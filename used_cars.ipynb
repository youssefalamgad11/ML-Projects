# %% [markdown]
# Imports

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score



# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# %%
for dirname, _, filenames in os.walk('cars.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
pd.set_option('display.max_columns', 100)

# %%
cars = pd.read_csv('cars.csv')
cars.head()
cars = cars.drop(columns=['feature_0','feature_1','feature_2','feature_3','feature_4','feature_5','feature_6','feature_7','feature_8','feature_9'], axis=1)
cars.head()
cars.shape
cars.describe()
cars.columns
cars.dtypes
cars.isnull().sum()
cars = cars.dropna()
cars.isnull().sum()

# %%
cars['age'] = 2023 - cars['year_produced']
cars.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0  universal         False  owned        all   10900.00            False
# 1  universal         False  owned        all    5000.00             True
# 2        suv         False  owned        all    2800.00             True
# 3      sedan         False  owned        all    9999.00             True
# 4  universal         False  owned        all    2134.11             True
#
#    location_region  number_of_photos  up_counter  duration_listed  age
# 0     Минская обл.                 9          13               16   13
# 1     Минская обл.                12          54               83   21
# 2     Минская обл.                 4          72              151   22
# 3     Минская обл.                 9          42               86   24
# 4  Гомельская обл.                14           7                7   22

# %%
cars_numeric = cars.select_dtypes(include=['float64', 'int64'])
cars_numeric.head()
# Out:
#    odometer_value  year_produced  engine_capacity  price_usd  \
# 0          190000           2010              2.5   10900.00
# 1          290000           2002              3.0    5000.00
# 2          402000           2001              2.5    2800.00
# 3           10000           1999              3.0    9999.00
# 4          280000           2001              2.5    2134.11
#
#    number_of_photos  up_counter  duration_listed  age
# 0                 9          13               16   13
# 1                12          54               83   21
# 2                 4          72              151   22
# 3                 9          42               86   24
# 4                14           7                7   22

# %%
cars['price_usd'] = cars['price_usd'].astype('float64')
temp = cars.copy()
table = temp.groupby(['manufacturer_name'])['price_usd'].mean()
temp = temp.merge(table.reset_index(), how='left', on='manufacturer_name')
table
# Out:
# manufacturer_name
# Acura            12772.885909
# Alfa Romeo        2688.550097
# Audi              7154.944923
# BMW               9532.098405
# Buick            12876.319149
# Cadillac         11093.124651
# Chery             4545.978103
# Chevrolet         8863.759885
# Chrysler          4995.491780
# Citroen           4433.126204
# Dacia             5342.751525
# Daewoo            1576.608733
# Dodge             5608.011953
# Fiat              2979.752689
# Ford              4993.888044
# Geely             7769.232535
# Great Wall        6423.760278
# Honda             6515.096474
# Hyundai           7926.190394
# Infiniti         13794.604938
# Iveco            10052.317122
# Jaguar           17813.000000
# Jeep             10912.489439
# Kia               8156.095526
# LADA              7598.681370
# Lancia            2901.508370
# Land Rover       15195.300380
# Lexus            17130.560845
# Lifan             8280.536170
# Lincoln           9737.472222
# Mazda             4731.527101
# Mercedes-Benz     9389.817072
# Mini             13133.700882
# Mitsubishi        5416.170800
# Nissan            6386.446010
# Opel              4425.992900
# Peugeot           4382.217727
# Pontiac           4363.544048
# Porsche          18629.823770
# Renault           4557.398873
# Rover             1734.242213
# Saab              4130.585370
# Seat              3868.015347
# Skoda            13795.448466
# SsangYong         7719.322405
# Subaru            7522.094605
# Suzuki            5302.598761
# Toyota            9798.152456
# Volkswagen        6428.902578
# Volvo             8416.341540
# ВАЗ               1518.921289
# ГАЗ               3889.731900
# ЗАЗ               1360.211190
# Москвич            978.912182
# УАЗ               3443.123784
# Name: price_usd, dtype: float64

# %%
cars.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0  universal         False  owned        all   10900.00            False
# 1  universal         False  owned        all    5000.00             True
# 2        suv         False  owned        all    2800.00             True
# 3      sedan         False  owned        all    9999.00             True
# 4  universal         False  owned        all    2134.11             True
#
#    location_region  number_of_photos  up_counter  duration_listed  age
# 0     Минская обл.                 9          13               16   13
# 1     Минская обл.                12          54               83   21
# 2     Минская обл.                 4          72              151   22
# 3     Минская обл.                 9          42               86   24
# 4  Гомельская обл.                14           7                7   22

# %%
scaler = MinMaxScaler()
num_vars = ['price_usd','year_produced']
cars[num_vars] = scaler.fit_transform(cars[num_vars])
cars.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0       0.883117    gasoline           False    gasoline              2.5
# 1       0.779221    gasoline           False    gasoline              3.0
# 2       0.766234    gasoline           False    gasoline              2.5
# 3       0.740260    gasoline           False    gasoline              3.0
# 4       0.766234    gasoline           False    gasoline              2.5
#
#    body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0  universal         False  owned        all   0.217984            False
# 1  universal         False  owned        all   0.099982             True
# 2        suv         False  owned        all   0.055981             True
# 3      sedan         False  owned        all   0.199964             True
# 4  universal         False  owned        all   0.042663             True
#
#    location_region  number_of_photos  up_counter  duration_listed  age
# 0     Минская обл.                 9          13               16   13
# 1     Минская обл.                12          54               83   21
# 2     Минская обл.                 4          72              151   22
# 3     Минская обл.                 9          42               86   24
# 4  Гомельская обл.                14           7                7   22

# %%
X = cars.drop(['price_usd'], axis=1)
y = cars['price_usd']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 21)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (26964, 20)
# (11557, 20)
# (26964,)
# (11557,)

# %%
cars.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0       0.883117    gasoline           False    gasoline              2.5
# 1       0.779221    gasoline           False    gasoline              3.0
# 2       0.766234    gasoline           False    gasoline              2.5
# 3       0.740260    gasoline           False    gasoline              3.0
# 4       0.766234    gasoline           False    gasoline              2.5
#
#    body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0  universal         False  owned        all   0.217984            False
# 1  universal         False  owned        all   0.099982             True
# 2        suv         False  owned        all   0.055981             True
# 3      sedan         False  owned        all   0.199964             True
# 4  universal         False  owned        all   0.042663             True
#
#    location_region  number_of_photos  up_counter  duration_listed  age
# 0     Минская обл.                 9          13               16   13
# 1     Минская обл.                12          54               83   21
# 2     Минская обл.                 4          72              151   22
# 3     Минская обл.                 9          42               86   24
# 4  Гомельская обл.                14           7                7   22

# %%
cars = cars[cars["engine_fuel"].isin(cars["engine_type"])]

# %%
cars['engine_fuel'].value_counts()
# Out:
# gasoline    24065
# diesel      12872
# Name: engine_fuel, dtype: int64

# %%
cars['location_region'].value_counts()
# Out:
# Минская обл.        23398
# Гомельская обл.      3014
# Витебская обл.       2896
# Брестская обл.       2784
# Могилевская обл.     2527
# Гродненская обл.     2318
# Name: location_region, dtype: int64

# %%
cars_df = pd.read_csv("modified_cars.csv")
cars_df.head()
# Out:
#    transmission  odometer_value  year_produced  engine_fuel  engine_has_gas  \
# 0             1          190000       0.883117            0           False
# 1             1          290000       0.779221            0           False
# 2             1          402000       0.766234            0           False
# 3             0           10000       0.740260            0           False
# 4             1          280000       0.766234            0           False
#
#    engine_capacity  has_warranty  drivetrain  price_usd  is_exchangeable  \
# 0              2.5         False           2   0.217984            False
# 1              3.0         False           2   0.099982             True
# 2              2.5         False           2   0.055981             True
# 3              3.0         False           2   0.199964             True
# 4              2.5         False           2   0.042663             True
#
#    number_of_photos  up_counter  duration_listed  age
# 0                 9          13               16   13
# 1                12          54               83   21
# 2                 4          72              151   22
# 3                 9          42               86   24
# 4                14           7                7   22

# %%
value_map_ehg = {'FALSE':0, 'TRUE':1}
cars_df["engine_has_gas"] = cars_df["engine_has_gas"].map(value_map_ehg).fillna(cars_df["engine_has_gas"])

value_map_hw = {'FALSE':0, 'TRUE':1}
cars_df["has_warranty"] = cars_df["has_warranty"].map(value_map_hw).fillna(cars_df["has_warranty"])


value_map_ex = {'FALSE':0, 'TRUE':1}
cars_df["is_exchangeable"] = cars_df["is_exchangeable"].map(value_map_ex).fillna(cars_df["is_exchangeable"])

new_path = "final_cars.csv"
cars_df.to_csv(new_path,index=False)

# %%
cars_df = pd.read_csv("modified_cars.csv")

# %%
cars_df.head()
# Out:
#    transmission  odometer_value  engine_fuel  engine_capacity  drivetrain  \
# 0             1          190000            0              2.5           2
# 1             1          290000            0              3.0           2
# 2             1          402000            0              2.5           2
# 3             0           10000            0              3.0           2
# 4             1          280000            0              2.5           2
#
#    price_usd  number_of_photos  up_counter  duration_listed  age
# 0   0.217984                 9          13               16   13
# 1   0.099982                12          54               83   21
# 2   0.055981                 4          72              151   22
# 3   0.199964                 9          42               86   24
# 4   0.042663                14           7                7   22

# %%
cars_df["engine_fuel"].value_counts()
# Out:
# 0    24065
# 1    12872
# Name: engine_fuel, dtype: int64

# %%
X = cars_df.drop(['price_usd'], axis=1)
y = cars_df['price_usd']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 21)

# %% [markdown]
# Linear Regression Model

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
lm_y_pred = lm.predict(X_test)
print(lm.coef_)
print(lm.intercept_)
lm_mse = mean_squared_error(lm_y_pred, y_test)
lm_r2 = r2_score(lm_y_pred, y_test)
print(f"Mean Squared Error: {lm_mse}")
print(f"R2 Score: {lm_r2}")
# Out:
# [ 2.19633230e-02 -1.33915326e-07  2.66805508e-02  2.60083676e-02
#   4.02410406e-02  1.99388665e-03  2.79073310e-05  1.51082507e-05
#  -8.92541403e-03]
# 0.23766474482673003
# Mean Squared Error: 0.005671291513385428
# R2 Score: 0.49523719512611986

# %% [markdown]
# Random Forest

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)

rfr_y_pred = rfr.predict(X_test)
rfr_mse = mean_squared_error(rfr_y_pred, y_test)
rfr_r2 = r2_score(rfr_y_pred, y_test)
print(f"Mean Squared Error: {rfr_mse}")
print(f"R2 Score: {rfr_r2}")
# Out:
# Mean Squared Error: 0.0022291783365670508
# R2 Score: 0.8529616738260144

# %% [markdown]
# KNN

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

knn_y_pred = knn.predict(X_test)
knn_mse = mean_squared_error(knn_y_pred, y_test)
knn_r2 = r2_score(knn_y_pred, y_test)
print(f"Mean Squared Error: {knn_mse}")
print(f"R2 Score: {knn_r2}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 knn = KNeighborsClassifier()
# ----> 2 knn.fit(X_train, y_train)
#       4 knn_y_pred = knn.predict(X_test)
#       5 knn_mse = mean_squared_error(knn_y_pred, y_test)
#
# File c:\Users\LAPTOP\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\LAPTOP\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:228, in KNeighborsClassifier.fit(self, X, y)
#     206 @_fit_context(
#     207     # KNeighborsClassifier.metric is not validated yet
#     208     prefer_skip_nested_validation=False
#     209 )
#     210 def fit(self, X, y):
#     211     """Fit the k-nearest neighbors classifier from the training dataset.
#     212
#     213     Parameters
#    (...)
#     226         The fitted k-nearest neighbors classifier.
#     227     """
# --> 228     return self._fit(X, y)
#
# File c:\Users\LAPTOP\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:480, in NeighborsBase._fit(self, X, y)
#     477 else:
#     478     self.outputs_2d_ = True
# --> 480 check_classification_targets(y)
#     481 self.classes_ = []
#     482 # Using `dtype=np.intp` is necessary since `np.bincount`
#     483 # (called in _classification.py) fails when dealing
#     484 # with a float64 array on 32bit systems.
#
# File c:\Users\LAPTOP\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:215, in check_classification_targets(y)
#     207 y_type = type_of_target(y, input_name="y")
#     208 if y_type not in [
#     209     "binary",
#     210     "multiclass",
#    (...)
#     213     "multilabel-sequences",
#     214 ]:
# --> 215     raise ValueError(
#     216         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     217         "classifier, which expects discrete classes on a "
#     218         "regression target with continuous values."
#     219     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
lm_cv_score = cross_val_score(lm, X_train, y_train, cv=5)
print(f"Linear Regression cross validation score: {lm_cv_score}")
# Out:
# Linear Regression cross validation score: [0.65876463 0.66995463 0.66555075 0.64407869 0.6481265 ]

# %%
rfr_cv_score = cross_val_score(rfr, X_train, y_train, cv=5)
print(f"Random Forest Regression cross validation: {rfr_cv_score}")
# Out:
# Random Forest Regression cross validation: [0.87295541 0.87234069 0.86663064 0.86044573 0.85792035]

# %%
if lm_cv_score.mean() > rfr_cv_score.mean():
    mld_select = lm
    print("Linear Regression Model is selected.")
else:
    mld_select = rfr
    print("Random Forest Regression is selected.")
    
    selected_model = mld_select.fit(X_train, y_train)
print(selected_model)
# Out:
# Random Forest Regression is selected.
# RandomForestRegressor()

# %%
final_pred = selected_model.predict(X_test)
final_pred
fnl_rfr_mse = mean_squared_error(final_pred, y_test)
fnl_rfr_r2 = r2_score(final_pred, y_test)
print(f"Mean Squared Error: {fnl_rfr_mse}")
print(f"R2 Score: {fnl_rfr_r2}")

lm_acc = lm.score(X_test, y_test)
print(f"Linear model accurcy score : {lm_acc}")
rfr_acc = rfr.score(X_test,y_test)
print(f"Random Forest Regression accurcy score : {lm_acc}")
# Out:
# Mean Squared Error: 0.002216637795493246
# R2 Score: 0.8535683202327871
# Linear model accurcy score : 0.6612307585923843
# Random Forest Regression accurcy score : 0.6612307585923843

# %% [markdown]
# Try here

# %%
new_data = [1,190000,0,2.5,2,0.21798436,9,13,16,13]
new_data = np.array(new_data)
new_data.reshape(-1,1)
# Out:
# array([[1.0000000e+00],
#        [1.9000000e+05],
#        [0.0000000e+00],
#        [2.5000000e+00],
#        [2.0000000e+00],
#        [2.1798436e-01],
#        [9.0000000e+00],
#        [1.3000000e+01],
#        [1.6000000e+01],
#        [1.3000000e+01]])

# %%
# Assuming you have new data in the variable 'new_data'
linear_predictions = lm.predict(new_data)

# %%
# Assuming you have new data in the variable 'new_data'
rf_predictions = rfr.predict(new_data)

# %%
linear_mse = mean_squared_error(true_labels, linear_predictions)
linear_r2 = r2_score(true_labels, linear_predictions)

rf_mse = mean_squared_error(true_labels, rf_predictions)
rf_r2 = r2_score(true_labels, rf_predictions)

print(f"Linear Regression MSE: {linear_mse}, R-squared: {linear_r2}")
print(f"Random Forest MSE: {rf_mse}, R-squared: {rf_r2}")
